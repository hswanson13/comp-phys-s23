# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#PART A


def func(x,t,m): #function wishing to integrate
    return (1/np.pi) * np.cos(m*t - x*np.sin(t))

def J(x,n,m):
    a=0
    b=np.pi
    
    delt_x = (b-a)/n
    t_s = np.arange(a,b+delt_x, delt_x) #x0 = a , x1 = a + delt_x , x2 = a + 2 delt_x , etc...

    integral = 0
    for i in range(2,n+1):
        integral += 2*func(x,t_s[i-2],m) + 4*func(x,t_s[i-1],m) + func(x,t_s[i],m)
        
    return integral


x = np.linspace(0,20,1000)

c = ['red','green','blue']

plt.figure(figsize=(10,10))
for i in range(3):
    plt.plot(x,J(x,1000,i),c[i])

plt.xlabel('x')
plt.ylabel('J')
plt.show()

# %%
#PART B
import matplotlib.cm as cm

#density plot

N = 100
r = np.linspace(0,1*10**(-6),N)
t = np.linspace(0,2*np.pi,N)

R, T = np.meshgrid(r, t, indexing='ij')

def I(r):
    k = (2*np.pi)/(500*10**(-9))
    return (J(k*r,N,1)/(k*r))**2 

intensity = I(R)
intensity[0] = np.zeros_like(intensity[0])+0.5

ax = plt.subplot(111, polar=True)
ax.set_yticklabels([])
ctf = ax.contourf(T, R, intensity, cmap=cm.jet)
plt.colorbar(ctf)
#ax.plot(T,R)
# Out:
# /tmp/ipykernel_16179/2536292881.py:14: RuntimeWarning: divide by zero encountered in true_divide
#   return (J(k*r,N,1)/(k*r))**2
